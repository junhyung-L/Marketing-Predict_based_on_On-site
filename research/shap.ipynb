# %%
# %cd /mnt/d/LJH/predict
# !python xgb.py --shap-only --shap-sample-size all
# Out:
# /mnt/d/LJH/predict
# [DEVICE] Detected device for XGBoost: cuda
# [LOAD] Loading dataset from: /mnt/d/LJH/data/final_data_100k_64.parquet
# [MEMORY OPTIMIZATION] Fast downcasting feature dtypes...
# [DATASET CHECK] Total Rows: 9,999,329 | Positives: 12,340 | Target Imbalance Ratio: 0.123408%
# [COST-SENSITIVE] Full Train Set Negative/Positive Ratio = 809.32
# [SHAP ONLY] Loading existing fold models from: /mnt/d/LJH/predict/models

# %%
# %cd /mnt/d/LJH/predict
# !python plot_xgb_shap_topn.py --top-n 30 --plot-sample-size all
# Out:
# /mnt/d/LJH/predict
# [FONT] Korean plot font: NanumGothic
# [FOUND] SHAP NPZ file: /mnt/d/LJH/predict/shap/shap_values_xgb_all_ensemble.npz (2,290.4 MB)
# [LOAD] Reading saved SHAP values: /mnt/d/LJH/predict/shap/shap_values_xgb_all_ensemble.npz
# [LOADED] shap_values=(9999329, 64) | feature_values=(9999329, 64) | features=64
# [PLOT] Drawing 30 features with 9,999,329 rows
# [SAVED] Top-30 SHAP plot and CSV in: /mnt/d/LJH/predict/shap

# %%
# !python tune_missing_only.py --data "/mnt/d/LJH/data/final_data_64.parquet" --trials 10 --epochs 2 --max-rows 100000
# Out:
# RF {'fixed_all_best_params': {'pos_weight': 1.0059696244768448, 'n_estimators': 200, 'max_depth': 16}, 'missing_only_best_params': {'min_samples_split': 2, 'min_samples_leaf': 2}, 'validation_pr_auc': 0.6816156772496462}
# MLP {'fixed_all_best_params': {'pos_weight': 14.126101375282198, 'hidden_dim': 64, 'lr': 0.008597863855323283, 'dropout': 0.3962968545354246}, 'missing_only_best_params': {'n_layers': 3, 'l2': 0.003788145521097122, 'batch_size': 128}, 'validation_pr_auc': 0.6937457588322735}
# CNN {'fixed_all_best_params': {'pos_weight': 2.3109194364678345, 'num_filters': 128, 'lr': 0.00853034202936806, 'dropout': 0.16970609854442822}, 'missing_only_best_params': {'kernel_size': 3, 'pool_size': 3, 'num_conv_layers': 1, 'l2': 1.6193110912440743e-05, 'batch_size': 128}, 'validation_pr_auc': 0.6641340910716353}
# ...
